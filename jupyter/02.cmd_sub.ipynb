# %%
import rospy
from geometry_msgs.msg import Twist

# %%
class MiniPiSub:
    def __init__(self):
        rospy.init_node('jupyter_lab_sub')

        self.cmd_sub=rospy.Subscriber("/cmd_vel/joy", Twist, self.cmd_cb)
    
    def cmd_cb(self, msg: Twist):
        print(f"linear.x: {msg.linear.x}, angular.z: {msg.angular.z}", flush=True)

# %%
if __name__ == "__main__":
    MiniPiSub()
    rate = rospy.Rate(10) # 10Hz로 루프 속도 설정
    
    print("ROS Subscriber Node started. Waiting for messages on /cmd_vel...")
    
    while not rospy.is_shutdown():
        rospy.spin() 
        
        rate.sleep()
# Out:
# ROS Subscriber Node started. Waiting for messages on /cmd_vel...
# linear.x: 0.35287717580795286, angular.z: 0.0
# linear.x: 0.5875291585922241, angular.z: 0.0
# linear.x: 0.5675604343414307, angular.z: 0.0
# linear.x: 0.49267762899398804, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: -0.23801835179328917, angular.z: 0.0
# linear.x: -0.6, angular.z: 0.0
# linear.x: -0.6, angular.z: 0.0
# linear.x: -0.6, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: 0.01838145889341831, angular.z: 0.0
# linear.x: 0.14318609833717347, angular.z: 0.0
# linear.x: 0.19312723875045776, angular.z: 0.0
# linear.x: 0.20810378193855286, angular.z: 0.0
# linear.x: 0.13819391727447508, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: 0.40281829833984373, angular.z: 0.0
# linear.x: 0.5975135564804077, angular.z: 0.0
# linear.x: 0.5975135564804077, angular.z: 0.0
# linear.x: 0.5975135564804077, angular.z: 0.0
# linear.x: 0.18813503980636595, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: -0.5225921988487243, angular.z: 0.0
# linear.x: -0.5924828052520752, angular.z: 0.0
# linear.x: -0.10820225179195404, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: -0.6, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: -0.6, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: -0.003366352245211601, angular.z: 0.0
# linear.x: -0.008358537778258323, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: -0.14813973605632783, angular.z: 0.0
# linear.x: -0.1131944328546524, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: -0.2579870939254761, angular.z: 0.0
# linear.x: -0.17310066819190978, angular.z: 0.0
# linear.x: -0.0283272810280323, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: -0.28794021606445314, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: 0.003404902014881372, angular.z: 0.0
# linear.x: 0.10324861407279969, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: -0.1631162881851196, angular.z: 0.0
# linear.x: -0.16810848712921142, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: 0.23306472301483153, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: -0.0782491385936737, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: 0.12820954620838165, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: 0.07329550087451935, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: 0.003404902014881372, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.0
# linear.x: 0.0, angular.z: -0.6
# linear.x: 0.0, angular.z: -0.6
# linear.x: 0.0, angular.z: -0.4576937913894653
# linear.x: 0.0, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.5276229500770568
# linear.x: 0.0, angular.z: 0.5925213575363159
# linear.x: 0.0, angular.z: 0.07828769087791443
# linear.x: 0.0, angular.z: 0.0
# linear.x: 0.0, angular.z: -0.1980808675289154
# linear.x: 0.0, angular.z: -0.23801835179328917
# linear.x: 0.0, angular.z: -0.013350723311305046
# linear.x: 0.0, angular.z: -0.5026234745979309
# linear.x: 0.0, angular.z: -0.5924828052520752
# linear.x: 0.0, angular.z: 0.0
# linear.x: 0.0, angular.z: 0.08327987194061279
# linear.x: 0.0, angular.z: 0.12321735620498657
# linear.x: 0.0, angular.z: 0.12820954620838165
# linear.x: 0.0, angular.z: 0.0
